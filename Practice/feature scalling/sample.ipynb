# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('SampleFile.csv')
df.max()
# Out:
# LotArea       215245
# MSSubClass       190
# dtype: int64

# %%
import numpy as np
max_vals = np.max(np.abs(df))
max_vals
# Out:
# np.int64(215245)

# %%
df
df2= pd.DataFrame((df-max_vals)/max_vals)

# %%
df2
# Out:
#        LotArea  MSSubClass
# 0    -0.960742   -0.999721
# 1    -0.955400   -0.999907
# 2    -0.947734   -0.999721
# 3    -0.955632   -0.999675
# 4    -0.933750   -0.999721
# ...        ...         ...
# 1455 -0.963219   -0.999721
# 1456 -0.938791   -0.999907
# 1457 -0.957992   -0.999675
# 1458 -0.954856   -0.999907
# 1459 -0.953834   -0.999907
#
# [1460 rows x 2 columns]

# %%
fig ,(ax1,ax2) = plt.subplots(ncols=2,figsize=(12,5))

ax1.scatter(df['LotArea'],df['MSSubClass'])
ax1.set_title('Before Scalling')
ax2.scatter(df2['LotArea'],df2['MSSubClass'],color='Red')
ax2.set_title('After Scalling')

plt.show()
